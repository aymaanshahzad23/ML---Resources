# %% [markdown]
# # K-means Clustering
# ------
# - Take a random guess about the centre of the two clusters
# <br>

# %% [markdown]
# ### Finding Cluster Centroids
#
# ![image.png](attachment:image.png)

# %% [markdown]
# It labels new points red or blue depending upon their relative distance from the inital guess of cluster centroids

# %% [markdown]
# ## Recompute Cluster Centroids
#
# ![image.pngb](attachment:image.png)

# %% [markdown]
# ----
# ### Reassigning labels to the points after updating cluster centroid position
#
# ![alt text](image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### We keep doing this averaging (finding new centroids) and re-labelling
# ![image.png](attachment:image.png)

# %% [markdown]
# ### The new centroids shift as a result of the new cluster centroids
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Finally we end up with this
# ![image.png](attachment:image.png)
